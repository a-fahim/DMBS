# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# ## 3.1 HYPOTHESIS TESTING VERSUS EXPLORATORY DATA ANALYSIS

# %% [markdown]
# When approaching a data mining problem, a data mining analyst may already have some a priori hypotheses that he or she would like to test regarding the relationships between the variables.
#
# However, analysts do not always have a priori notions of the expected relationships among the variables. Especially when confronted with unknown, large databases, analysts often prefer to use exploratory data analysis (EDA), or graphical data analysis. EDA allows the analyst to
# * Delve into the data set;
# * Examine the inter-relationships among the attributes;
# * Identify interesting subsets of the observations; and
# * Develop an initial idea of possible associations among the predictors, as well as between the predictors and the target variable.

# %% [markdown]
# ## 3.2 GETTING TO KNOW THE DATA SET

# %%
import numpy as np
import pandas as pd

input_file = "./data_sets/churn.txt"

df = pd.read_csv(input_file)
print(df.dtypes)
df.head()
# Out:
# State              object
# Account Length      int64
# Area Code           int64
# Phone              object
# Int'l Plan         object
# VMail Plan         object
# VMail Message       int64
# Day Mins          float64
# Day Calls           int64
# Day Charge        float64
# Eve Mins          float64
# Eve Calls           int64
# Eve Charge        float64
# Night Mins        float64
# Night Calls         int64
# Night Charge      float64
# Intl Mins         float64
# Intl Calls          int64
# Intl Charge       float64
# CustServ Calls      int64
# Churn?             object
# dtype: object
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan
# 0    KS             128        415  382-4657         no        yes  \
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# ...

# %% [markdown]
# ## 3.3 EXPLORING CATEGORICAL VARIABLES

# %%
# pd.crosstab(df['Churn?'], df["Int'l Plan"],margins=True)
# pd.crosstab(df['Churn?'], df["Int'l Plan"],margins=True,normalize=True)
pd.crosstab(index=[df['Churn?'], df["Int'l Plan"]], columns=[df['VMail Plan']])
# Out:
# VMail Plan           no  yes
# Churn? Int'l Plan
# False. no          1878  786
#        yes          130   56
# True.  no           302   44
#        yes          101   36

# %%
df.groupby(["Int'l Plan",'Churn?']).size().unstack().plot(kind='bar')
plt.show()

# %% [markdown]
# ## 3.4 EXPLORING NUMERIC VARIABLES

# %%
import matplotlib.pyplot as plt
df.select_dtypes(np.number).boxplot()
plt.xticks(rotation=90)
plt.show()

# %%
df.select_dtypes(np.number).hist(figsize=(10, 10))
plt.show()

# %% [markdown]
# ## 3.5 EXPLORING MULTIVARIATE RELATIONSHIPS

# %% [markdown]
# <img src="./img/L03.05.00.png" width=30%>

# %% [markdown]
# ## 3.6 SELECTING INTERESTING SUBSETS OF THE DATA FOR FURTHER INVESTIGATION

# %% [markdown]
# To summarize the strategy we implemented here.
# 1. Generate multivariate graphical EDA, such as scatter plots with a flag overlay.
# 2. Use these plots to uncover subsets of interesting records.
# 3. Quantify the differences by analyzing the subsets of records.

# %% [markdown]
# <img src="./img/L03.05.01.png" width=30%>

# %% [markdown]
# ## 3.7 USING EDA TO UNCOVER ANOMALOUS FIELDS

# %% [markdown]
# <img src="./img/L03.07.00.png" width=40%>

# %% [markdown]
# ## 3.8 BINNING BASED ON PREDICTIVE VALUE

# %% [markdown]
# <img src="./img/L03.08.00.png" width=40%> <br>
# <img src="./img/L03.08.01.png" width=40%> <br>
# <img src="./img/L03.08.02.png" width=40%>

# %% [markdown]
# ## 3.9 DERIVING NEW VARIABLES: FLAG VARIABLES

# %% [markdown]
# <img src="./img/L03.09.01.png" width=40% style="border: 2px solid black;"> <br> <br>
# <img src="./img/L03.09.02.png" width=40% style="box-shadow: 10px 10px 5px grey;"> <br> <br>
# <img src="./img/L03.09.00.png" width=40% style="border: 2px solid black;"> <br>
# <img src="./img/L03.09.03.png" width=40% style="border: 2px solid;">

# %% [markdown]
# ## 3.10 DERIVING NEW VARIABLES: NUMERICAL VARIABLES

# %% [markdown]
# <img src="./img/L03.10.00.png" width=40% style="border: 2px solid black;"> <br> <br>
# <img src="./img/L03.10.01.png" width=40% style="box-shadow: 10px 10px 5px grey;"> <br>
# <img src="./img/L03.10.02.png" width=40% style="box-shadow: 10px 10px 5px grey;"> <br> <br>
# <img src="./img/L03.10.03.png" width=40%  style="border: 2px solid black;"> <br>

# %% [markdown]
# <img src="./img/L03.10.04.png" width=40% style="box-shadow: 10px 10px 5px grey;"> <br> <br>
# <img src="./img/L03.10.05.png" width=40% style="border: 2px solid black;"> <br>

# %% [markdown]
# **EXERCISES**
# 16, 17
